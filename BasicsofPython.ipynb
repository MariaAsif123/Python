# %%
#Practice python for Basics of python syntax, print statement, variables, strings, logical operators, basic math operations

# %%
#Chapter 01 --Print statement
print("Hello, World!")

print("""This is a multi-line string.
It spans multiple lines.
Python is awesome!""")

name = "Maria"
age = 20
print(f"My name is {name} and I am {age} years old.")
# Out:
# Hello, World!
# This is a multi-line string.
# It spans multiple lines.
# Python is awesome!
# My name is Maria and I am 20 years old.

# %%
# chapter 02 & 03 variables for strings& numbers, logical operators and 

name = "Mark"
print(name)

greeting = "Hello"
name = "Alice"
message = greeting + ", " + name + "!"
print(message)


message = "Hello, World!"
print("The length of the message is:", len(message))


name = "Alice"
greeting = f"Hello, {name}!"
print(greeting)

#variables for numbers
addition = 5 + 3
subtraction = 10 - 4
multiplication = 7 * 2
division = 16 / 2
print(f"Addition: {addition}")
print(f"Subtraction: {subtraction}")
print(f"Multiplication: {multiplication}")
print(f"Division: {division}")

age = 25
message = "I am " + str(age) + " years old."
print(message)

number = 10
number += 1
print(f"The new value is {number}")
 # variables for floats
a = 2.5
b = 4.2
print(f"Addition: {a + b}")
print(f"Subtraction: {a - b}")
print(f"Multiplication: {a * b}")
print(f"Division: {a / b}")

#variables for boolean
is_python_fun = True
if is_python_fun:
    print("Python is fun!")
else:
    print("Python is not fun!")
# logical operators
a = True
b = False
print(f"a AND b: {a and b}")
print(f"a OR b: {a or b}")
print(f"NOT a: {not a}")

#toggles
is_on = True
is_on = not is_on
print(f"The toggled value is {is_on}")
# Out:
# Mark
# Hello, Alice!
# The length of the message is: 13
# Hello, Alice!
# Addition: 8
# Subtraction: 6
# Multiplication: 14
# Division: 8.0
# I am 25 years old.
# The new value is 11
# Addition: 6.7
# Subtraction: -1.7000000000000002
# Multiplication: 10.5
# Division: 0.5952380952380952
# Python is fun!
# a AND b: False
# a OR b: True
# NOT a: False
# The toggled value is False

# %%
#Basic Math Operations

a = 10
b = 5
print(f"Addition: {a + b}")
print(f"Subtraction: {a - b}")
print(f"Multiplication: {a * b}")
print(f"Division: {a / b}")


#Task 2: Calculate the square root of a number

import math
number = 16
square_root = math.sqrt(number)
print(f"The square root of {number} is {square_root}")

#Task 3: Calculate the power of a number

base = 2
exponent = 3
result = pow(base, exponent)
print(f"{base} raised to the power of {exponent} is {result}")

#Task 4: Find the remainder of a division

dividend = 10
divisor = 3
remainder = dividend

dividend = 10
divisor = 3
remainder = dividend % divisor
print(f"The remainder of {dividend} divided by {divisor} is {remainder}")
#Task 5: Perform compound arithmetic operations

a = 5
b = 2
result = (a + b) * (a - b)
print(f"The result of the compound operation is {result}")

#Concatenating Strings

#Task 1: Concatenate two strings and print the result

str1 = "Hello"
str2 = "World"
result = str1 + " " + str2
print(result)

#Task 2: Concatenate a string and a number

age = 25
message = "I am " + str(age) + " years old."
print(message)

#Task 3: Use f-strings to concatenate strings

name = "Alice"
age = 25
message = f"My name is {name} and I am {age} years old."
print(message)

#Task 4: Concatenate multiple strings in a loop

words = ["Python", "is", "fun"]
sentence = ""
for word in words:
    sentence += word + " "
print(sentence.strip())

#Task 5: Create a formatted string using placeholders
name = "Alice"
age = 25
message = "My name is {} and I am {} years old.".format(name, age)
print(message)
# Out:
# Addition: 15
# Subtraction: 5
# Multiplication: 50
# Division: 2.0
# The square root of 16 is 4.0
# 2 raised to the power of 3 is 8
# The remainder of 10 divided by 3 is 1
# The result of the compound operation is 21
# Hello World
# I am 25 years old.
# My name is Alice and I am 25 years old.
# Python is fun
# My name is Alice and I am 25 years old.
